# %%
import pandas as pd

# %%
# 1. Loading a CSV dataset into a Pandas DataFrame
df = pd.read_csv("D:\\New folder\\celebal\\assignment 1\\Combined_dataset.csv")
df
# Out:
#      product_id           title  \
# 0       8376765     Lino Perros
# 1       9136281  Tommy Hilfiger
# 2      17633752           Lavie
# 3       1376949          F Gear
# 4      13939916       MYTRIDENT
# ..          ...             ...
# 995    13698258           KREDO
# 996    16896006           GUESS
# 997     1708108        GIORDANO
# 998    19280114        Fastrack
# 999    18601682         BOLDFIT
#
#                                    product_description  rating  ratings_count  \
# 0                       Women Navy Blue Solid Backpack     3.8             15
# 1                    Unisex Navy Blue Striped Backpack     4.5             67
# 2                       Aries Women Pink Mini Backpack     4.4            226
# 3           Unisex Navy & Grey Printed Burner Backpack     4.4           1052
# 4                             Men Blue Solid Bath Robe     4.7             12
# ..                                                 ...     ...            ...
# ...

# %%
# 2. Exploring Data
df.head()
# Out:
#    product_id           title                         product_description  \
# 0     8376765     Lino Perros              Women Navy Blue Solid Backpack
# 1     9136281  Tommy Hilfiger           Unisex Navy Blue Striped Backpack
# 2    17633752           Lavie              Aries Women Pink Mini Backpack
# 3     1376949          F Gear  Unisex Navy & Grey Printed Burner Backpack
# 4    13939916       MYTRIDENT                    Men Blue Solid Bath Robe
#
#    rating  ratings_count  initial_price  discount  final_price currency  \
# 0     3.8             15           3995      58.0  "₹3,995.00"      INR
# 1     4.5             67           2899      35.0  "₹2,899.00"      INR
# 2     4.4            226           2999      65.0  "₹2,999.00"      INR
# 3     4.4           1052           1675      52.0  "₹1,675.00"      INR
# 4     4.7             12           2899      17.0  "₹2,899.00"      INR
#
#                                               images  ...  \
# ...

# %%
df.tail()
# Out:
#      product_id     title                                product_description  \
# 995    13698258     KREDO  Men FORTE Silver Automatic Skeleton Analogue W...
# 996    16896006     GUESS  Women White Patterned Dial & White Straps Anal...
# 997     1708108  GIORDANO  Women Rose Gold-Toned Mirrored Analogue Watch ...
# 998    19280114  Fastrack  Men Black Brass Dial & Black Stainless Steel S...
# 999    18601682   BOLDFIT                           Purple Textured Yoga Mat
#
#      rating  ratings_count  initial_price  discount   final_price currency  \
# 995     3.5             11          11890      50.0  "₹11,890.00"      INR
# 996     5.0             22           8900      45.0   "₹8,900.00"      INR
# 997     2.8              5           7950      50.0   "₹7,950.00"      INR
# 998     4.3             17           3295      20.0   "₹2,636.00"      INR
# 999     3.8            161            699      31.0     "₹699.00"      INR
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   product_id              1000 non-null   int64
#  1   title                   1000 non-null   str
#  2   product_description     1000 non-null   str
#  3   rating                  1000 non-null   float64
#  4   ratings_count           1000 non-null   int64
#  5   initial_price           1000 non-null   int64
#  6   discount                879 non-null    float64
#  7   final_price             1000 non-null   str
#  8   currency                1000 non-null   str
#  9   images                  1000 non-null   str
#  10  delivery_options        1000 non-null   str
#  11  product_details         1000 non-null   str
#  12  breadcrumbs             1000 non-null   str
#  13  product_specifications  1000 non-null   str
#  14  amount_of_stars         1000 non-null   str
# ...

# %%
df.describe()
# Out:
#          product_id     rating  ratings_count  initial_price    discount
# count  1.000000e+03  1000.0000    1000.000000     1000.00000  879.000000
# mean   1.713437e+07     3.6215      76.691000     2723.24100   53.503982
# std    3.813766e+06     1.3744     241.114263     2408.69736   18.029201
# min    5.868460e+05     0.0000       0.000000      249.00000    1.000000
# 25%    1.511501e+07     3.7000       7.000000     1399.00000   44.000000
# 50%    1.820890e+07     4.1000      17.000000     1999.00000   56.000000
# 75%    1.902737e+07     4.3000      58.000000     3299.00000   66.000000
# max    2.274707e+07     5.0000    4441.000000    22199.00000   88.000000

# %%
df.dtypes
# Out:
# product_id                  int64
# title                         str
# product_description           str
# rating                    float64
# ratings_count               int64
# initial_price               int64
# discount                  float64
# final_price                   str
# currency                      str
# images                        str
# delivery_options              str
# product_details               str
# breadcrumbs                   str
# product_specifications        str
# amount_of_stars               str
# what_customers_said           str
# seller_name                   str
# sizes                         str
# videos                        str
# seller_information            str
# variations                    str
# best_offer                    str
# more_offers                   str
# category                      str
# dtype: object

# %%
df.shape
# Out:
# (1000, 24)

# %%
df.columns
# Out:
# Index(['product_id', 'title', 'product_description', 'rating', 'ratings_count',
#        'initial_price', 'discount', 'final_price', 'currency', 'images',
#        'delivery_options', 'product_details', 'breadcrumbs',
#        'product_specifications', 'amount_of_stars', 'what_customers_said',
#        'seller_name', 'sizes', 'videos', 'seller_information', 'variations',
#        'best_offer', 'more_offers', 'category'],
#       dtype='str')

# %%
# 3. Handling missing values
df.isnull().sum()
# Out:
# product_id                  0
# title                       0
# product_description         0
# rating                      0
# ratings_count               0
# initial_price               0
# discount                  121
# final_price                 0
# currency                    0
# images                      0
# delivery_options            0
# product_details             0
# breadcrumbs                 0
# product_specifications      0
# amount_of_stars             0
# what_customers_said       573
# seller_name               301
# sizes                       0
# videos                    781
# seller_information        301
# variations                562
# best_offer                  0
# more_offers                 0
# category                    0
# dtype: int64

# %%
df["discount"] = df["discount"].fillna(0)
df["seller_name"] = df["seller_name"].fillna("Unknown")
df["seller_information"] = df["seller_information"].fillna("Not Available")
df["variations"] = df["variations"].fillna("No Variations")
df
# Out:
#      product_id           title  \
# 0       8376765     Lino Perros
# 1       9136281  Tommy Hilfiger
# 2      17633752           Lavie
# 3       1376949          F Gear
# 4      13939916       MYTRIDENT
# ..          ...             ...
# 995    13698258           KREDO
# 996    16896006           GUESS
# 997     1708108        GIORDANO
# 998    19280114        Fastrack
# 999    18601682         BOLDFIT
#
#                                    product_description  rating  ratings_count  \
# 0                       Women Navy Blue Solid Backpack     3.8             15
# 1                    Unisex Navy Blue Striped Backpack     4.5             67
# 2                       Aries Women Pink Mini Backpack     4.4            226
# 3           Unisex Navy & Grey Printed Burner Backpack     4.4           1052
# 4                             Men Blue Solid Bath Robe     4.7             12
# ..                                                 ...     ...            ...
# ...

# %%
df = df.drop(columns=['what_customers_said', 'videos'])

# %%
df.isnull().sum()
# Out:
# product_id                0
# title                     0
# product_description       0
# rating                    0
# ratings_count             0
# initial_price             0
# discount                  0
# final_price               0
# currency                  0
# images                    0
# delivery_options          0
# product_details           0
# breadcrumbs               0
# product_specifications    0
# amount_of_stars           0
# seller_name               0
# sizes                     0
# seller_information        0
# variations                0
# best_offer                0
# more_offers               0
# category                  0
# dtype: int64

# %%
# 4. 4 Performing basic operations
df.columns
# Out:
# Index(['product_id', 'title', 'product_description', 'rating', 'ratings_count',
#        'initial_price', 'discount', 'final_price', 'currency', 'images',
#        'delivery_options', 'product_details', 'breadcrumbs',
#        'product_specifications', 'amount_of_stars', 'seller_name', 'sizes',
#        'seller_information', 'variations', 'best_offer', 'more_offers',
#        'category'],
#       dtype='str')

# %%
df[['title', 'initial_price', 'discount']]
# Out:
#               title  initial_price  discount
# 0       Lino Perros           3995      58.0
# 1    Tommy Hilfiger           2899      35.0
# 2             Lavie           2999      65.0
# 3            F Gear           1675      52.0
# 4         MYTRIDENT           2899      17.0
# ..              ...            ...       ...
# 995           KREDO          11890      50.0
# 996           GUESS           8900      45.0
# 997        GIORDANO           7950      50.0
# 998        Fastrack           3295      20.0
# 999         BOLDFIT            699      31.0
#
# [1000 rows x 3 columns]

# %%
df[['title', 'initial_price', 'rating']][df['discount']>75]
# Out:
#                          title  initial_price  rating
# 16               DREAM WEAVERZ           2599     3.8
# 17                      Arrabi           6329     4.3
# 18                     Kastner           1399     3.8
# 21                     Mactree           9060     3.9
# 38                   KARATCART           3397     4.6
# ..                         ...            ...     ...
# 925               Dennis Lingo           3099     3.8
# 963                    BULLMER           3998     4.8
# 965  AMERICAN EAGLE OUTFITTERS           1799     4.4
# 976                 Art Street           3500     3.9
# 990                  TIMESMITH           2499     3.7
#
# [69 rows x 3 columns]

# %%
df[(df['rating']>4.2) & (df['initial_price']<2500) & (df['discount']>60)]
# Out:
#      product_id                      title  \
# 52     22436508                Bruchi CLUB
# 57     16281444                 Bharatasya
# 107    18962984                     Athena
# 128    17692718             Style Quotient
# 129    17194598              Tokyo Talkies
# 133    18996672                 Bella Moda
# 143    10691426                  SASSAFRAS
# 145    18963006                     Athena
# 155    20046216                  YK Disney
# 169    13406942                Global Desi
# 171    13387582                  Wish Karo
# 178    13449506                     DOOR74
# 202    12999996                    Vishudh
# 209    10564232          PRITA BY PRIYAASI
# 217    20041906                  KARATCART
# 220    22601952                       SOHI
# 224    14399558                    Shoshaa
# 249    19990734                  VASTRAMAY
# 422    21184968                   HERE&NOW
# 480    13428018                        ETC
# 489    15973760             Zoom Minimondo
# ...

# %%
df.iloc[:, [0,6]]
# Out:
#      product_id  discount
# 0       8376765      58.0
# 1       9136281      35.0
# 2      17633752      65.0
# 3       1376949      52.0
# 4      13939916      17.0
# ..          ...       ...
# 995    13698258      50.0
# 996    16896006      45.0
# 997     1708108      50.0
# 998    19280114      20.0
# 999    18601682      31.0
#
# [1000 rows x 2 columns]

# %%
df.iloc[0:6, 1:4]
# Out:
#             title                         product_description  rating
# 0     Lino Perros              Women Navy Blue Solid Backpack     3.8
# 1  Tommy Hilfiger           Unisex Navy Blue Striped Backpack     4.5
# 2           Lavie              Aries Women Pink Mini Backpack     4.4
# 3          F Gear  Unisex Navy & Grey Printed Burner Backpack     4.4
# 4       MYTRIDENT                    Men Blue Solid Bath Robe     4.7
# 5             H&M  Beige & Tan Solid Stoneware Soap Dispenser     4.5

# %%
# 5. Removing duplicates
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# 6. Create a derived column  (savings = price * discount/100)
df['savings'] = df['initial_price'] * df['discount']/100
df
# Out:
#      product_id           title  \
# 0       8376765     Lino Perros
# 1       9136281  Tommy Hilfiger
# 2      17633752           Lavie
# 3       1376949          F Gear
# 4      13939916       MYTRIDENT
# ..          ...             ...
# 995    13698258           KREDO
# 996    16896006           GUESS
# 997     1708108        GIORDANO
# 998    19280114        Fastrack
# 999    18601682         BOLDFIT
#
#                                    product_description  rating  ratings_count  \
# 0                       Women Navy Blue Solid Backpack     3.8             15
# 1                    Unisex Navy Blue Striped Backpack     4.5             67
# 2                       Aries Women Pink Mini Backpack     4.4            226
# 3           Unisex Navy & Grey Printed Burner Backpack     4.4           1052
# 4                             Men Blue Solid Bath Robe     4.7             12
# ..                                                 ...     ...            ...
# ...

# %%
# 7. Saving the cleaned dataset as a new CSV file
df.to_csv("Cleaned_dataset.csv", index=False)
